# %% [markdown]
# <a href="https://colab.research.google.com/github/PadmavathiGamini/FMML-COURSE-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-10 06:11:02--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   211MB/s    in 0.3s
#
# 2023-06-10 06:11:04 (211 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 425    1708.07689v1  Recently, deep neural networks have demonstrat...  stat
# 7419   1712.07106v2  Two-dimensional embeddings remain the dominant...  stat
# 26850  1701.00405v2  Generalization performance of trained computer...    cs
# 13130  1703.00734v2  Bayesian matrix factorization (BMF) is a power...  stat
# 13178  1712.07581v1  A general Boltzmann machine with continuous vi...  stat
# ...             ...                                                ...   ...
# 33273   0804.4237v1  Neurons are modeled electrically based on ferr...    cs
# 28454  1706.07342v7  Automated cardiac image interpretation has the...    cs
# 23043  1802.06967v1  We study the problem of recovery of matrices t...  stat
# 33069  1802.00910v2  We present, GeniePath, a scalable approach for...    cs
# 16580  1704.03560v1  This paper describes Luminoso's participation ...    cs
#
#                                                    title  year  \
# 425    Understanding and Comparing Deep Neural Networ...  2017
# 7419   Exploring High-Dimensional Structure via Axis-...  2017
# 26850               Adversarially Tuned Scene Generation  2017
# 13130  Distributed Bayesian Matrix Factorization with...  2017
# 13178                    Riemann-Theta Boltzmann Machine  2017
# ...                                                  ...   ...
# 33273  Explaining the Logical Nature of Electrical So...  2008
# 28454  A Computer Vision Pipeline for Automated Deter...  2017
# 23043  Recovery of simultaneous low rank and two-way ...  2018
# 33069  GeniePath: Graph Neural Networks with Adaptive...  2018
# 16580  ConceptNet at SemEval-2017 Task 2: Extending W...  2017
#
#                                                 keywords
# 425    [demonstrated, excellent, performances, recogn...
# 7419   [dimensional, embeddings, visualize, dimension...
# 26850  [generalization, performance, generated, effec...
# 13130  [factorization, producing, representations, pr...
# 13178  [boltzmann, continuous, introduced, assumption...
# ...                                                  ...
# 33273  [electrically, ferroelectric, membranes, conje...
# 28454  [automated, interpretation, potential, transfo...
# 23043  [simultaneously, applications, cognitive, neur...
# 33069  [geniepath, receptive, permutation, invariant,...
# 16580  [describes, luminosos, participation, multilin...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 425      [demonstrated, excellent, performances, recogn...
# 7419     [dimensional, embeddings, visualize, dimension...
# 26850    [generalization, performance, generated, effec...
# 13130    [factorization, producing, representations, pr...
# 13178    [boltzmann, continuous, introduced, assumption...
#                                ...
# 33605    [computational, framework, visualization, func...
# 15621    [introduce, translation, sentences, sequences,...
# 591      [investigate, prediction, adaptation, correcti...
# 22073    [graphical, selection, dimensional, stationary...
# 19560    [extension, cumulative, constraint, constraine...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8906 words.
# Out of those 4562 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="24a1b4b3-ff0c-403d-ba12-7af90df69ad5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24a1b4b3-ff0c-403d-ba12-7af90df69ad5")) {                    Plotly.newPlot(                        "24a1b4b3-ff0c-403d-ba12-7af90df69ad5",                        [{"x":["preprocessing","pretraining","comparing","considered","alignment","recognizing","architectures","initialization","relevance","strategies","parameter","challenging","classification","evaluations","demonstrated","representations","prediction","combination","architecture","performances","conditions","intuitively","compensating","understanding","recognition","propagation","information","algorithm","performance","visualizes","robustness","benchmark","different","investigating","excellent","evaluates","perception","compromise","exploring","particular","components","intuitive","visualize","integrated","relations","representatives","complexity","difficult","combinations","visualizations","interpret","decomposition","dimensional","projections","bivariate","furthermore","structure","resulting","displayed","projection","neighborhood","quantitatively","interpreting","introduce","interpretability","nevertheless","relationships","directions","embeddings","significantly","visualization","interactive","described","posterior","effective","laborious","transferability","especially","annotating","initially","measuring","graphical","augmented","simulated","stochastic","discriminatively","estimation","collections","iterative","framework","generative","separability","generalization","distributions","convolutional","demonstrate","adversarially","improvements","unsupervised","adversarial","generated","bootstrapping","cityscapes","discrepancy","respectively","parameters","generation","rejection","intrinsic","iterations","communication","predicting","computations","embarrassingly","distributing","computation","distribution","factorization","inferences","approximate","confidence","implementation","solutions","distributed","magnitude","predictive","completely","inference","empirically","unidentifiability","independent","hierarchical","bottleneck","producing","efficient","computational","intervals","negligible","derivative","logarithmic","continuous","boltzmann","functions","probability","techniques","analytically","involving","expectation","introduced","modelling","increasing","successfully","activation","connection","conditional","parametric","assumptions","feedforward","optimization","calculated","regularized","traditional","nonlinear","underlying","algorithms","exponential","corrective","obtaining","summarization","similarity","correlation","therefore","retrieval","euclidean","automatically","necessary","coefficient","experimental","accompanied","eliminate","clustering","important","effectively","documents","divergence","generalize","primitive","implemented","guarantees","temporally","mitigates","misspecification","iteration","convergence","uncertainty","reinforcement","acquiring","exhibiting","correlations","depending"],"y":[34,8,67,121,50,32,128,20,36,97,129,269,492,37,98,237,213,141,268,37,141,11,0,160,400,77,674,836,872,1,118,205,735,16,26,11,35,5,31,246,116,32,17,52,83,2,215,154,34,6,30,79,162,22,4,160,337,135,7,50,17,28,16,349,19,17,81,51,85,281,37,48,78,41,252,9,6,133,9,26,29,64,50,52,131,6,189,27,75,539,129,6,124,117,366,563,4,110,137,101,170,6,7,10,86,228,145,5,45,28,54,62,36,0,5,136,199,40,10,117,39,127,150,103,62,49,36,206,75,0,106,103,21,33,412,280,14,11,9,10,124,16,229,166,371,10,53,37,113,59,117,71,25,37,93,31,51,15,320,33,31,178,54,112,573,51,4,42,24,145,69,125,106,36,176,85,27,377,7,11,127,342,133,78,20,65,10,92,61,22,5,1,41,119,63,122,10,16,31,40],"type":"bar"},{"x":["preprocessing","pretrai ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4562,), (4562, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Costing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generated</span> <span style=''>Runtime</span> <span style='background-color:rgba(0, 255, 0, 0.7674418604651163);'>Execution</span> <span style=''>Plans</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>Programs</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 1.0);'>Declarative</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>(ML)</span> <span style=''>aims</span> <span style=''>at</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4482758620689656);'>specification</span> <span style=''>of</span> <span style=''>ML</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style=''>a</span> <span style=''>high</span> <span style=''>level</span> <span style=''>language</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6290322580645162);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.5025906735751295);'>generation</span> <span style=''>of</span> <span style=''>hybrid</span> <span style=''>runtime</span> <span style='background-color:rgba(0, 255, 0, 0.7674418604651163);'>execution</span> <span style=''>plans</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>single</span> <span style=''>node</span> <span style=''>in</span> <span style=''>memory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computations</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computations</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>MapReduce</span> <span style=''>(MR)</span> <span style=''>or</span> <span style=''>similar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frameworks</span> <span style=''>like</span> <span style=''>Spark</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>compilation</span> <span style=''>of</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>ML</span> <span style=''>programs</span> <span style=''>exhibits</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>opportunities</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.6290322580645162);'>automatic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>Advanced</span> <span style=''>cost</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>require</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>precondition</span> <span style=''>an</span> <span style=''>accurate</span> <span style=''>cost</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.35483870967741943);'>evaluating</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3191489361702128);'>decisions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>share</span> <span style=''>insights</span> <span style=''>into</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>robust</span> <span style=''>yet</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Convex</span> <span style=''>Coupled</span> <span style=''>Matrix</span> <span style=''>and</span> <span style=''>Tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Completion</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>convex</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>inducing</span> <span style=''>norms</span> <span style=''>for</span> <span style=''>a</span> <span style=''>coupled</span> <span style=''>matrices</span> <span style=''>and</span> <span style=''>tensors</span> <span style=''>(hereafter</span> <span style=''>coupled</span> <span style=''>tensors)</span> <span style=''>which</span> <span style=''>shares</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>between</span> <span style=''>matrices</span> <span style=''>and</span> <span style=''>tensors</span> <span style=''>through</span> <span style=''>common</span> <span style=''>modes</span> <span style=''>More</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overlapped</span> <span style=''>trace</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>norms</span> <span style=''>with</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>trace</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>then</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>norms</span> <span style=''>A</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>norms</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>convex</span> <span style=''>and</span> <span style=''>can</span> <span style=''>find</span> <span style=''>a</span> <span style=''>globally</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>while</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>coupled</span> <span style=''>learning</span> <span style=''>are</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>bounds</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>by</span> <span style=''>our</span> <span style=''>proposed</span> <span style=''>norms</span> <span style=''>which</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>proposed</span> <span style=''>norms</span> <span style=''>can</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>low</span> <span style=''>rankness</span> <span style=''>of</span> <span style=''>coupled</span> <span style=''>tensors</span> <span style=''>leading</span> <span style=''>to</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>Step</span> <span style='background-color:rgba(255, 0, 0, 0.3316326530612245);'>Stochastic</span> <span style=''>ADMM</span> <span style=''>in</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.38842975206611574);'>Dimensions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>to</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>and</span> <span style=''>Noisy</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>ADMM</span> <span style=''>method</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3068181818181817);'>guarantees</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3898305084745763);'>dimensional</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>explicit</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>the</span> <span style=''>noisy</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>problem</span> <span style=''>For</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>that</span> <span style=''>the</span> <span style=''>modified</span> <span style=''>ADMM</span> <span style=''>method</span> <span style=''>has</span> <span style=''>an</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.321937321937322);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>mathcalO(slog</span> <span style=''>dT)</span> <span style=''>where</span> <span style=''>s</span> <span style=''>is</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>level</span> <span style=''>d</span> <span style=''>is</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3242009132420091);'>dimension</span> <span style=''>and</span> <span style=''>T</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>steps</span> <span style=''>This</span> <span style=''>matches</span> <span style=''>with</span> <span style=''>the</span> <span style=''>minimax</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>For</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>into</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3068181818181817);'>guarantees</span> <span style=''>for</span> <span style=''>any</span> <span style=''>online</span> <span style=''>method</span> <span style=''>and</span> <span style=''>prove</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.321937321937322);'>convergence</span> <span style=''>rate</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>PSF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Introduction</span> <span style=''>to</span> <span style=''>R</span> <span style=''>Package</span> <span style=''>for</span> <span style=''>Pattern</span> <span style=''>Sequence</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forecasting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discusses</span> <span style=''>about</span> <span style=''>an</span> <span style=''>R</span> <span style=''>package</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implements</span> <span style=''>the</span> <span style=''>Pattern</span> <span style=''>Sequence</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forecasting</span> <span style=''>(PSF)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>univariate</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>fields</span> <span style=''>The</span> <span style=''>PSF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>two</span> <span style=''>major</span> <span style=''>parts</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>part</span> <span style=''>includes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>of</span> <span style=''>the</span> <span style=''>optimum</span> <span style=''>number</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>It</span> <span style=''>labels</span> <span style=''>time</span> <span style=''>series</span> <span style=''>data</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reference</span> <span style=''>to</span> <span style=''>such</span> <span style=''>clusters</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>part</span> <span style=''>includes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>like</span> <span style=''>optimum</span> <span style=''>window</span> <span style=''>size</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>for</span> <span style=''>specific</span> <span style=''>patterns</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>future</span> <span style=''>values</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reference</span> <span style=''>to</span> <span style=''>past</span> <span style=''>pattern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>The</span> <span style=''>PSF</span> <span style=''>package</span> <span style=''>consists</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12968917470525188)
# 	segmentation (0.07002500893176135)
# 	processing (0.1082529474812433)
# 	knowledge (0.13004644515898536)
# 	architecture (0.09574848160057163)
# 	information (0.24080028581636298)
# 	detection (0.12290103608431582)
# 	convolutional (0.1307609860664523)
# 	different (0.26259378349410506)
# 	recognition (0.1429081814933905)
#
# Some Statistics words are:
# 	stochastic (0.13043478260869565)
# 	algorithm (0.38980509745127434)
# 	theoretical (0.14942528735632185)
# 	estimation (0.16541729135432284)
# 	variables (0.1409295352323838)
# 	statistical (0.15592203898050974)
# 	distribution (0.1774112943528236)
# 	dimensional (0.18440779610194902)
# 	inference (0.20589705147426288)
# 	regression (0.18640679660169915)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="78e81551-66eb-4523-a951-bbe622825aa2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78e81551-66eb-4523-a951-bbe622825aa2")) {                    Plotly.newPlot(                        "78e81551-66eb-4523-a951-bbe622825aa2",                        [{"x":["preprocessing","pretraining","comparing","considered","alignment","recognizing","architectures","initialization","relevance","strategies","parameter","challenging","classification","evaluations","demonstrated","representations","prediction","combination","architecture","performances","conditions","intuitively","compensating","understanding","recognition","propagation","information","algorithm","performance","visualizes","robustness","benchmark","different","investigating","excellent","evaluates","perception","compromise","exploring","particular","components","intuitive","visualize","integrated","relations","representatives","complexity","difficult","combinations","visualizations","interpret","decomposition","dimensional","projections","bivariate","furthermore","structure","resulting","displayed","projection","neighborhood","quantitatively","interpreting","introduce","interpretability","nevertheless","relationships","directions","embeddings","significantly","visualization","interactive","described","posterior","effective","laborious","transferability","especially","annotating","initially","measuring","graphical","augmented","simulated","stochastic","discriminatively","estimation","collections","iterative","framework","generative","separability","generalization","distributions","convolutional","demonstrate","adversarially","improvements","unsupervised","adversarial","generated","bootstrapping","cityscapes","discrepancy","respectively","parameters","generation","rejection","intrinsic","iterations","communication","predicting","computations","embarrassingly","distributing","computation","distribution","factorization","inferences","approximate","confidence","implementation","solutions","distributed","magnitude","predictive","completely","inference","empirically","unidentifiability","independent","hierarchical","bottleneck","producing","efficient","computational","intervals","negligible","derivative","logarithmic","continuous","boltzmann","functions","probability","techniques","analytically","involving","expectation","introduced","modelling","increasing","successfully","activation","connection","conditional","parametric","assumptions","feedforward","optimization","calculated","regularized","traditional","nonlinear","underlying","algorithms","exponential","corrective","obtaining","summarization","similarity","correlation","therefore","retrieval","euclidean","automatically","necessary","coefficient","experimental","accompanied","eliminate","clustering","important","effectively","documents","divergence","generalize","primitive","implemented","guarantees","temporally","mitigates","misspecification","iteration","convergence","uncertainty","reinforcement","acquiring","exhibiting","correlations","depending","geometric","densities","suggested","balancing","requirements","inefficient","exponentially","exploiting","transient","frequency","increases","exploitation","stationary","mahalanobis","generally","attention","evaluated","increased","considerable","phenomenon","methodologies","manifests","comparative","evaluation","implement","properties","technology","dissimilarity","constraints","hybridizes","detection","challenges","statistic","scenarios","advantage","existence","phenomena","collected","mechanism","sensitive","environmental","established","statistical","measurements","technique","monitoring","component","processing","preliminary","principal","predictions","application","temperature","resour ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	compensating
# 	embarrassingly
# 	unidentifiability
# 	nonnegativity
# 	misspecified
# 	immigration
# 	contextualizing
# 	covariates
# 	confounder
# 	unscented
# 	micrographs
# 	pediatric
# 	ergodicity
# 	electrocardiograms
# 	algebraically
# 	parsimony
# 	hypergraphs
# 	smoothers
# 	advocates
# 	ameliorate
# Some words which never appear in Statistics papers:
# 	annotating
# 	cityscapes
# 	manifests
# 	hybridizes
# 	manipulation
# 	orderings
# 	syntactic
# 	photographer
# 	photographs
# 	saturated
# 	stylistic
# 	functionalities
# 	attractiveness
# 	googlenet
# 	syntactical
# 	messaging
# 	prerequisite
# 	notations
# 	formalisms
# 	characterising

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.072007864340133e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
